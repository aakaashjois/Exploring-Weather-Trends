# %%
import os
import pandas as pd
import plotly.offline as py
from plotly.graph_objs import Layout
import cufflinks as cf

# %%
py.init_notebook_mode(connected=True)
PATH_TO_DATA = os.path.join(os.getcwd(), 'data')
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
city_data = pd.read_csv(os.path.join(PATH_TO_DATA, 'city_data.csv'))
global_data = pd.read_csv(os.path.join(PATH_TO_DATA, 'global_data.csv'))

# %%
new_york_rows = city_data.index[city_data['city'] == 'New York']
bangalore_rows = city_data.index[city_data['city'] == 'Bangalore']

# %%
new_york_data = pd.DataFrame(city_data.iloc[new_york_rows]).fillna(method='ffill')
bangalore_data = pd.DataFrame(city_data.iloc[bangalore_rows]).fillna(method='ffill')
global_data = global_data.fillna(method='ffill')

# %%
new_york_data = new_york_data.drop(columns=['city', 'country'])
bangalore_data = bangalore_data.drop(columns=['city', 'country'])

# %%
merged = global_data.merge(new_york_data, on='year').merge(bangalore_data, on='year')
merged.columns = ['year', 'Global', 'NYC', 'Bangalore']
merged = merged.set_index('year')
merged = merged.rolling(window=3, center=True, min_periods=1).mean()

# %%
py.iplot({'data': [{'x': merged.index, 
                    'y': merged[col], 
                    'name': col
                   } for col in merged.columns],
          'layout': Layout(title='Average temperature trend',
                           xaxis=dict(title='Year'),
                           yaxis=dict(title='Celcius'))
         }, filename='average-temperature-trend')
# Out:
# <div id="e2c0353c-3ea3-4a2b-a2dc-775483867538" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("e2c0353c-3ea3-4a2b-a2dc-775483867538", [{"x": [1796, 1797, 1798, 1799, 1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809, 1810, 1811, 1812, 1813, 1814, 1815, 1816, 1817, 1818, 1819, 1820, 1821, 1822, 1823, 1824, 1825, 1826, 1827, 1828, 1829, 1830, 1831, 1832, 1833, 1834, 1835, 1836, 1837, 1838, 1839, 1840, 1841, 1842, 1843, 1844, 1845, 1846, 1847, 1848, 1849, 1850, 1851, 1852, 1853, 1854, 1855, 1856, 1857, 1858, 1859, 1860, 1861, 1862, 1863, 1864, 1865, 1866, 1867, 1868, 1869, 1870, 1871, 1872, 1873, 1874, 1875, 1876, 1877, 1878, 1879, 1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1
# ...
