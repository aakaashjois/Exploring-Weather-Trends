# %% [markdown]
# # Exploring Weather Trends

# %% [markdown]
# #### Udacity Data Analyst Nanodegree - Project 1

# %% [markdown]
# ## Import Statements

# %% [markdown]
# *pandas* - Used for reading managing the dataset provided
#
# *plotly* - Allows us to create amazing graphs and interactive visualization

# %%
import pandas
import plotly

# %% [markdown]
# ## Reading dataset

# %%
city_data = pandas.read_csv('./data/city_data.csv')
global_data = pandas.read_csv('./data/global_data.csv')

# %% [markdown]
# We will be focusing on just two cities, **Bangalore** and **New York**, and the global average temperatures. More cities can be added if needed

# %% [markdown]
# Finding the row indices where the temperature data for the cities needed is located in the dataset

# %%
bangalore_rows = city_data.index[city_data['city'] == 'Bangalore']
new_york_rows = city_data.index[city_data['city'] == 'New York']

# %% [markdown]
# Extracting the data from the dataset and saving it as Pandas DataFrame

# %%
new_york_data = pandas.DataFrame(city_data.iloc[new_york_rows])
bangalore_data = pandas.DataFrame(city_data.iloc[bangalore_rows])

# %%
new_york_data.head()
# Out:
#        year      city        country  avg_temp
# 46341  1743  New York  United States      3.26
# 46342  1744  New York  United States     11.66
# 46343  1745  New York  United States      1.13
# 46344  1746  New York  United States       NaN
# 46345  1747  New York  United States       NaN

# %%
bangalore_data.head()
# Out:
#       year       city country  avg_temp
# 6367  1796  Bangalore   India     24.49
# 6368  1797  Bangalore   India     25.18
# 6369  1798  Bangalore   India     24.65
# 6370  1799  Bangalore   India     24.81
# 6371  1800  Bangalore   India     24.85

# %%
global_data.head()
# Out:
#    year  avg_temp
# 0  1750      8.72
# 1  1751      7.98
# 2  1752      5.78
# 3  1753      8.39
# 4  1754      8.47

# %% [markdown]
# ## Processing data

# %% [markdown]
# We do not need to city and country columns. We are only concerned about the average temperature for each year. So the unwanted columns can be dropped.

# %%
new_york_data = new_york_data.drop(columns=['city', 'country'])
bangalore_data = bangalore_data.drop(columns=['city', 'country'])

# %% [markdown]
# We can observe that there are some NaN values in the average temperature column

# %%
new_york_data.isna().sum()
# Out:
# year        0
# avg_temp    5
# dtype: int64

# %%
bangalore_data.isna().sum()
# Out:
# year        0
# avg_temp    7
# dtype: int64

# %%
global_data.isna().sum()
# Out:
# year        0
# avg_temp    0
# dtype: int64

# %% [markdown]
# The number of NaN values is really small. We can use the Pandas methods to fill in those missing values

# %%
new_york_data = new_york_data.fillna(method='ffill')
bangalore_data = bangalore_data.fillna(method='ffill')

# %%
new_york_data.isna().sum()
# Out:
# year        0
# avg_temp    0
# dtype: int64

# %%
bangalore_data.isna().sum()
# Out:
# year        0
# avg_temp    0
# dtype: int64

# %% [markdown]
# We can now merge all the DataFrames to form a single DataFrame. We can observe that **year** column is common and that can be used as the reference for merging. The **year** column can be used as the index for this merged data.

# %%
merged = global_data.merge(new_york_data, on='year').merge(bangalore_data, on='year')
merged.columns = ['year', 'Global', 'NYC', 'Bangalore']
merged = merged.set_index('year')

# %% [markdown]
# ## Plotting

# %%
plotly.offline.init_notebook_mode(connected=True)
plotly.offline.iplot({'data': [{'x': merged.index, 
                                'y': merged[col], 
                                'name': col
                               } for col in merged.columns],
                      'layout': plotly.graph_objs.Layout(title='Average temperature trend',
                                                         xaxis=dict(title='Time in Year'),
                                                         yaxis=dict(title='Average Temperature in Celcius'))
                     }, filename='average-temperature-trend')
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="814557c8-aedc-452b-865c-a7228bf1f08f" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("814557c8-aedc-452b-865c-a7228bf1f08f", [{"x": [1796, 1797, 1798, 1799, 1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809, 1810, 1811, 1812, 1813, 1814, 1815, 1816, 1817, 1818, 1819, 1820, 1821, 1822, 1823, 1824, 1825, 1826, 1827, 1828, 1829, 1830, 1831, 1832, 1833, 1834, 1835, 1836, 1837, 1838, 1839, 1840, 1841, 1842, 1843, 1844, 1845, 1846, 1847, 1848, 1849, 1850, 1851, 1852, 1853, 1854, 1855, 1856, 1857, 1858, 1859, 1860, 1861, 1862, 1863, 1864, 1865, 1866, 1867, 1868, 1869, 1870, 1871, 1872, 1873, 1874, 1875, 1876, 1877, 1878, 1879, 1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013], "y": [8.27, 8.51, 8.67, 8.51, 8.48, 8.59, 8.58, 8.5, 8.84, 8.56, 8.43, 8.28, 7.63, 7.08, 6.92, 6.86, 7.05, 7.74, 7.59, 7.24, 6.94, 6.98, 7.83, 7.37, 7.62, 8.09, 8.19, 7.72, 8.55, 8.39, 8.36, 8.81, 8.17, 7.94, 8.52, 7.64, 7.45, 8.01, 8.15, 7.39, 7.7, 7.38, 7.51, 7.63, 7.8, 7.69, 8.02, 8.17, 7.65, 7.85, 8.55, 8.09, 7.98, 7.98, 7.9, 8.18, 8.1, 8.04, 8.21, 8.11, 8.0, 7.76, 8.1, 8.25, 7.96, 7.85, 7.56, 8.11, 7.98, 8.18, 8.29, 8.44, 8.25, 8.43, 8.2, 8.12, 8.19, 8.35, 8.43, 7.86, 8.08, 8.54, 8.83, 8.17, 8.12, 8.27, 8.13, 7.98, 7.77, 7.92, 7.95, 7.91, 8.09, 8.32, 7.97, 8.02, 8.07, 8.06, 8.16, 8.15, 8.21, 8.29, 8.18, 8.4, 8.5, 8.54, 8.3, 8.22, 8.09, 8.23, 8.38, 7.95, 8.19, 8.18, 8.22, 8.18, 8.17, 8.3, 8.59, 8.59, 8.23, 8.02, 8.13, 8.38, 8.36, 8.57, 8.41, 8.42, 8.51, 8.53, 8.73, 8.52, 8.63, 8.24, 8.63, 8.72, 8.71, 8.34, 8.63, 8.52, 8.55, 8.7, 8.86, 8.76, 8.76, 8.77, 8.73, 8.76, 8.85, 8.58, 8.68, 8.8, 8.75, 8.59, 8.37, 8.63, 8.64, 8.87, 8.56, 8.63, 8.28, 8.73, 8.77, 8.73, 8.58, 8.8, 8.75, 8.86, 8.41, 8.53, 8.6, 8.7, 8.52, 8.6, 8.7, 8.6, 8.5, 8.95, 8.47, 8.74, 8.35, 8.85, 8.69, 8.73, 8.98, 9.17, 8.64, 9.03, 8.69, 8.66, 8.83, 8.99, 9.2, 8.92, 9.23, 9.18, 8.84, 8.87, 9.04, 9.35, 9.04, 9.2, 9.52, 9.29, 9.2, 9.41, 9.57, 9.53, 9.32, 9.7, 9.53, 9.73, 9.43, 9.51, 9.7, 9.52, 9.51, 9.61], "name": "Global"}, {"x": [1796, 1797, 1798, 1799, 1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809, 1810, 1811, 1812, 1813, 1814, 1815, 1816, 1817, 1818, 1819, 1820, 1821, 1822, 1823, 1824, 1825, 1826, 1827, 1828, 1829, 1830, 1831, 1832, 1833, 1834, 1835, 1836, 1837, 1838, 1839, 1840, 1841, 1842, 1843, 1844, 1845, 1846, 1847, 1848, 1849, 1850, 1851, 1852, 1853, 1854, 1855, 1856, 1857, 1858, 1859, 1860, 1861, 1862, 1863, 1864, 1865, 1866, 1867, 1868, 1869, 1870, 1871, 1872, 1873, 1874, 1875, 1876, 1877, 1878, 1879, 1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1 ...

# %% [markdown]
# We can observe plot is not smooth and harder to read.

# %% [markdown]
#  A moving average will make the plot easier to visualize. We can using a moving window of size 3 for each data point for satisfying result

# %%
merged_mean = merged.rolling(window=3, center=True, min_periods=1).mean()
plotly.offline.init_notebook_mode(connected=True)
plotly.offline.iplot({'data': [{'x': merged_mean.index, 
                                'y': merged_mean[col], 
                                'name': col
                               } for col in merged_mean.columns],
                      'layout': plotly.graph_objs.Layout(title='Average temperature trend',
                                                         xaxis=dict(title='Time in Year'),
                                                         yaxis=dict(title='Average Temperature in Celcius'))
                     }, filename='average-temperature-trend')
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="434ec747-85f1-43de-9b9f-4181fbe23979" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("434ec747-85f1-43de-9b9f-4181fbe23979", [{"x": [1796, 1797, 1798, 1799, 1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809, 1810, 1811, 1812, 1813, 1814, 1815, 1816, 1817, 1818, 1819, 1820, 1821, 1822, 1823, 1824, 1825, 1826, 1827, 1828, 1829, 1830, 1831, 1832, 1833, 1834, 1835, 1836, 1837, 1838, 1839, 1840, 1841, 1842, 1843, 1844, 1845, 1846, 1847, 1848, 1849, 1850, 1851, 1852, 1853, 1854, 1855, 1856, 1857, 1858, 1859, 1860, 1861, 1862, 1863, 1864, 1865, 1866, 1867, 1868, 1869, 1870, 1871, 1872, 1873, 1874, 1875, 1876, 1877, 1878, 1879, 1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013], "y": [8.39, 8.483333333333334, 8.563333333333334, 8.553333333333335, 8.526666666666666, 8.549999999999999, 8.556666666666667, 8.639999999999999, 8.633333333333333, 8.61, 8.423333333333334, 8.113333333333332, 7.663333333333331, 7.209999999999998, 6.953333333333332, 6.9433333333333325, 7.216666666666666, 7.46, 7.5233333333333325, 7.256666666666665, 7.053333333333332, 7.249999999999997, 7.393333333333331, 7.606666666666665, 7.693333333333331, 7.966666666666662, 7.999999999999996, 8.153333333333327, 8.219999999999994, 8.433333333333328, 8.519999999999994, 8.44666666666666, 8.30666666666666, 8.209999999999994, 8.033333333333326, 7.869999999999993, 7.699999999999992, 7.869999999999993, 7.849999999999993, 7.74666666666666, 7.489999999999992, 7.529999999999991, 7.506666666666658, 7.6466666666666585, 7.706666666666659, 7.836666666666659, 7.959999999999993, 7.946666666666659, 7.889999999999993, 8.016666666666659, 8.163333333333325, 8.206666666666656, 8.016666666666655, 7.9533333333333225, 8.019999999999987, 8.059999999999986, 8.106666666666653, 8.116666666666653, 8.119999999999985, 8.106666666666653, 7.956666666666652, 7.953333333333319, 8.036666666666653, 8.10333333333332, 8.019999999999987, 7.789999999999986, 7.839999999999986, 7.883333333333319, 8.089999999999986, 8.149999999999986, 8.303333333333319, 8.326666666666652, 8.373333333333319, 8.293333333333317, 8.249999999999984, 8.169999999999982, 8.219999999999983, 8.323333333333316, 8.213333333333317, 8.123333333333315, 8.159999999999982, 8.483333333333315, 8.513333333333316, 8.373333333333315, 8.186666666666648, 8.173333333333316, 8.12666666666665, 7.959999999999983, 7.889999999999982, 7.879999999999981, 7.926666666666648, 7.983333333333316, 8.10666666666665, 8.12666666666665, 8.103333333333316, 8.019999999999984, 8.049999999999985, 8.096666666666653, 8.12333333333332, 8.17333333333332, 8.216666666666653, 8.226666666666652, 8.289999999999985, 8.359999999999985, 8.479999999999984, 8.446666666666651, 8.353333333333318, 8.203333333333317, 8.179999999999982, 8.233333333333315, 8.18666666666665, 8.173333333333316, 8.106666666666648, 8.196666666666648, 8.193333333333314, 8.189999999999982, 8.216666666666649, 8.353333333333318, 8.493333333333316, 8.469999999999983, 8.279999999999983, 8.12666666666665, 8.17666666666665, 8.289999999999981, 8.436666666666646, 8.446666666666646, 8.46666 ...

# %% [markdown]
# We can see that Bangalore's temeperature is always an approximately 2.5 higher than New York's temperatures. Although it is higher generally, we can see the ups and downs in the Bangalore's temperature coincides with most of the ups and downs in the global average temperature. New York's temperature is more erratic and has many peaks and troughs. But that too follows the global average tempeature's trend like Bangalore.

# %%
merged_large_mean = merged.rolling(window=len(merged), center=True, min_periods=1).mean()
plotly.offline.init_notebook_mode(connected=True)
plotly.offline.iplot({'data': [{'x': merged_large_mean.index, 
                                'y': merged_large_mean[col], 
                                'name': col
                               } for col in merged_large_mean.columns],
                      'layout': plotly.graph_objs.Layout(title='Average temperature trend',
                                                         xaxis=dict(title='Time in Year'),
                                                         yaxis=dict(title='Average Temperature in Celcius'))
                     }, filename='average-temperature-trend')
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="03a57fff-dc66-4590-896a-e239768f9aaa" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("03a57fff-dc66-4590-896a-e239768f9aaa", [{"x": [1796, 1797, 1798, 1799, 1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809, 1810, 1811, 1812, 1813, 1814, 1815, 1816, 1817, 1818, 1819, 1820, 1821, 1822, 1823, 1824, 1825, 1826, 1827, 1828, 1829, 1830, 1831, 1832, 1833, 1834, 1835, 1836, 1837, 1838, 1839, 1840, 1841, 1842, 1843, 1844, 1845, 1846, 1847, 1848, 1849, 1850, 1851, 1852, 1853, 1854, 1855, 1856, 1857, 1858, 1859, 1860, 1861, 1862, 1863, 1864, 1865, 1866, 1867, 1868, 1869, 1870, 1871, 1872, 1873, 1874, 1875, 1876, 1877, 1878, 1879, 1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013], "y": [8.041651376146788, 8.043363636363637, 8.046396396396396, 8.045535714285714, 8.046814159292037, 8.047982456140351, 8.049478260869567, 8.050603448275861, 8.051623931623931, 8.05372881355932, 8.058235294117647, 8.062666666666667, 8.064049586776859, 8.063688524590164, 8.064227642276423, 8.066774193548387, 8.06912, 8.073095238095238, 8.075748031496063, 8.078437500000001, 8.081782945736435, 8.08523076923077, 8.090152671755726, 8.093409090909091, 8.097443609022559, 8.09850746268657, 8.102444444444448, 8.10698529411765, 8.111386861313871, 8.113043478260872, 8.116762589928062, 8.11964285714286, 8.122695035460996, 8.126760563380286, 8.131888111888115, 8.136250000000002, 8.140551724137934, 8.144863013698632, 8.148843537414969, 8.152972972972975, 8.157651006711411, 8.160466666666668, 8.163907284768213, 8.16809210526316, 8.171895424836602, 8.17461038961039, 8.175870967741936, 8.178782051282052, 8.181719745222932, 8.186075949367089, 8.188427672955974, 8.191187500000002, 8.191739130434783, 8.195061728395062, 8.198588957055215, 8.201829268292684, 8.204121212121212, 8.207710843373494, 8.210958083832335, 8.214821428571428, 8.215976331360947, 8.217823529411765, 8.220058479532163, 8.222848837209302, 8.224566473988439, 8.226724137931033, 8.22942857142857, 8.23153409090909, 8.233050847457626, 8.237078651685392, 8.238379888268156, 8.241166666666667, 8.241767955801103, 8.24510989010989, 8.247540983606555, 8.25016304347826, 8.254108108108106, 8.259032258064515, 8.261069518716576, 8.265159574468084, 8.267407407407408, 8.269473684210526, 8.27240837696335, 8.276145833333333, 8.280932642487047, 8.284226804123712, 8.289076923076923, 8.293622448979592, 8.296395939086295, 8.29929292929293, 8.303015075376884, 8.30825, 8.311890547263681, 8.31628712871287, 8.322216748768472, 8.326960784313725, 8.331219512195121, 8.336456310679612, 8.342415458937198, 8.348125, 8.352775119617224, 8.359190476190475, 8.36473933649289, 8.371179245283018, 8.376150234741784, 8.38144859813084, 8.387581395348837, 8.392824074074074, 8.397972350230415, 8.403532110091742, 8.404147465437788, 8.403657407407406, 8.402418604651162, 8.401915887850466, 8.401549295774647, 8.40066037735849, 8.399810426540284, 8.399333333333333, 8.397224880382774, 8.396442307692308, 8.396280193236715, 8.396844660194175, 8.400585365853658, 8.407058823529411, 8.414384236453202, 8.422079207920792, 8.4289 ...

# %% [markdown]
# We can see that the temperature has been slowing rising for the past few centuries

# %% [markdown]
# ## Summary
